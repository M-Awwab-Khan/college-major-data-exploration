# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Awwab-Khan/college-major-data-exploration/blob/main/College_Major_Data_Exploration_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading data as dataframe

# %%
df = pd.read_csv('salaries_by_college_major.csv')

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Undergraduate Major                51 non-null     object
#  1   Starting Median Salary             50 non-null     float64
#  2   Mid-Career Median Salary           50 non-null     float64
#  3   Mid-Career 10th Percentile Salary  50 non-null     float64
#  4   Mid-Career 90th Percentile Salary  50 non-null     float64
#  5   Group                              50 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 2.5+ KB

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64

# %% [markdown]
# ### Questions
#
# How many rows does our dataframe have?
# Ans: 51
#
# How many columns does it have?
# Ans: 6
#
# What are the labels for the columns? Do the columns have names?
# Ans: Yes they have, 'Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'
#
# Are there any missing values in our dataframe? Does our dataframe contain any bad data?
# Ans: Yep there are a few missing values. The last row of dataset contains missing values. Solution: remove that row from our dataset.

# %%
cleaned = df.dropna()
cleaned.isnull().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               0
# Mid-Career Median Salary             0
# Mid-Career 10th Percentile Salary    0
# Mid-Career 90th Percentile Salary    0
# Group                                0
# dtype: int64

# %% [markdown]
# ### Find College Major with Highest Starting Salaries

# %%
cleaned[['Undergraduate Major', 'Starting Median Salary']]\
.sort_values(by='Starting Median Salary', ascending=False)\
.head()
# Out:
#        Undergraduate Major  Starting Median Salary
# 43     Physician Assistant                 74300.0
# 8     Chemical Engineering                 63200.0
# 12    Computer Engineering                 61400.0
# 19  Electrical Engineering                 60900.0
# 38  Mechanical Engineering                 57900.0

# %% [markdown]
# The highest starting salary is $74,300 of Physician Assistant

# %% [markdown]
# ### What college major has the highest mid-career salary? How much do graduates with this major earn?
# Mid-career is defined as having 10+ years of experience.

# %%
cleaned[['Undergraduate Major', 'Mid-Career Median Salary']]\
.sort_values(by='Mid-Career Median Salary', ascending=False)\
.head()
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
# 1    Aerospace Engineering                  101000.0
# 17               Economics                   98600.0

# %% [markdown]
# The highest mid career(10+ yrs experience) median salary is offered by chemical engineering i.e. $107000.

# %% [markdown]
# ### Which college major has the lowest starting salary and how much do graduates earn after university?

# %%
cleaned[['Undergraduate Major', 'Starting Median Salary']]\
.sort_values(by='Starting Median Salary')\
.head()
# Out:
#    Undergraduate Major  Starting Median Salary
# 49             Spanish                 34000.0
# 47            Religion                 34100.0
# 18           Education                 34900.0
# 15    Criminal Justice                 35000.0
# 34          Journalism                 35600.0

# %% [markdown]
# Hence graduates of Spanish major earn least after graduation i.e. $34000 per annum

# %% [markdown]
# ### Which college major has the lowest mid-career salary and how much can people expect to earn with this degree?

# %%
cleaned[['Undergraduate Major', 'Mid-Career Median Salary']]\
.sort_values(by='Mid-Career Median Salary')\
.head()
# Out:
#    Undergraduate Major  Mid-Career Median Salary
# 18           Education                   52000.0
# 47            Religion                   52000.0
# 49             Spanish                   53100.0
# 32     Interior Design                   53200.0
# 39               Music                   55000.0

# %% [markdown]
# Graduates of education and religion majors earn least mid career (10+ yrs experience) salary aournd $52000.

# %% [markdown]
# ### Lowest Risk Majors
# A low-risk major is a degree where there is a small difference between the lowest and highest salaries. In other words, if the difference between the 10th percentile and the 90th percentile earnings of your major is small, then you can be more certain about your salary after you graduate.

# %%
spread_col = cleaned['Mid-Career 90th Percentile Salary'] - cleaned['Mid-Career 10th Percentile Salary']
cleaned.insert(1, 'Spread', spread_col)
cleaned.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
low_risk = cleaned.sort_values(by='Spread')
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %% [markdown]
# It can be seen that Nursing is at great risk. Because the difference between highest and lowest salary after 10yrs is $50700.

# %% [markdown]
# ### Majors with the Highest Potential

# %%
highest_potential = cleaned.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %% [markdown]
# ### Majors with the Greatest Spread in Salaries

# %%
highest_spread = cleaned.sort_values('Spread', ascending=False)
highest_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %% [markdown]
# Notice how 3 of the top 5 are present in both. This means that there are some very high earning Economics degree holders out there, but also some who are not earning as much

# %% [markdown]
# ### Which category of degrees has the highest average salary? Is it STEM, Business or HASS (Humanities, Arts, and Social Science)?

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
cleaned.groupby('Group').mean()
# Out:
# <ipython-input-29-8d0f3bb539fb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cleaned.groupby('Group').mean()
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00

# %% [markdown]
# Notice STEM(Science, Technology, Engineering and Mathematics) have highest starting and mid career salaries, then Business and in the end HASS.
